# %% [markdown]
# # URLHAUS

# %%
import urlHaus as u
import importlib
importlib.reload(u)
# Out:
# <module 'urlHaus' from 'd:\\Documents\\School\\Programming\\Tech-Journal\\SYS-320\\Week 3\\classwork\\urlHaus.py'>

# %%
u.urlHausOpen('../../logs/urlHaus.csv', '.php')
# Out:
# URL: hxxps://imagingworld.edu/.win32.exe
# Info: https://urlhaus.abuse.ch/url/2018448/
# ************************************************************
#
# URL: hxxps://imagingworld.edu/.win32.exe
# Info: https://urlhaus.abuse.ch/url/2018448/
# ************************************************************
#
# URL: hxxps://imagingworld.edu/.win32.exe
# Info: https://urlhaus.abuse.ch/url/2018448/
# ************************************************************
#
# URL: hxxps://imagingworld.edu/.win32.exe
# Info: https://urlhaus.abuse.ch/url/2018448/
# ************************************************************
#
# URL: hxxps://imagingworld.edu/.win32.exe
# Info: https://urlhaus.abuse.ch/url/2018448/
# ************************************************************
#
# URL: hxxps://imagingworld.edu/.win32.exe
# Info: https://urlhaus.abuse.ch/url/2018448/
# ************************************************************
#
# URL: hxxps://imagingworld.edu/.win32.exe
# ...
